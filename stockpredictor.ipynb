# %%
which python3
# Out:
#   Cell In[1], line 1
#     which python3
#           ^
# SyntaxError: invalid syntax

# %%
python3 --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 python3 --version
#
# NameError: name 'python3' is not defined

# %%
x = np.random.randint(1, 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x = np.random.randint(1, 10)
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
pip list
# Out:
# Package                   Version
# ------------------------- --------------
# aniso8601                 9.0.1
# anyio                     4.8.0
# appnope                   0.1.4
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.4
# attrs                     24.3.0
# babel                     2.16.0
# beautifulsoup4            4.12.3
# bleach                    6.2.0
# blinker                   1.9.0
# certifi                   2024.12.14
# cffi                      1.17.1
# charset-normalizer        3.4.1
# click                     8.1.8
# comm                      0.2.2
# contourpy                 1.3.1
# cycler                    0.12.1
# debugpy                   1.8.11
# decorator                 5.1.1
# defusedxml                0.7.1
# executing                 2.1.0
# fastjsonschema            2.21.1
# Flask                     3.1.0
# Flask-RESTful             0.3.10
# fonttools                 4.55.3
# fqdn                      1.5.1
# frozendict                2.4.6
# h11                       0.14.0
# html5lib                  1.1
# httpcore                  1.0.7
# httpx                     0.28.1
# idna                      3.10
# ipykernel                 6.29.5
# ipython                   8.31.0
# ipywidgets                8.1.5
# isoduration               20.11.0
# itsdangerous              2.2.0
# jedi                      0.19.2
# Jinja2                    3.1.5
# joblib                    1.4.2
# json5                     0.10.0
# jsonpointer               3.0.0
# jsonschema                4.23.0
# jsonschema-specifications 2024.10.1
# jupyter                   1.1.1
# jupyter_client            8.6.3
# jupyter-console           6.6.3
# jupyter_core              5.7.2
# jupyter-events            0.11.0
# jupyter-lsp               2.2.5
# jupyter_server            2.15.0
# jupyter_server_terminals  0.5.3
# jupyterlab                4.3.4
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.3
# jupyterlab_widgets        3.0.13
# kiwisolver                1.4.8
# lxml                      5.3.0
# MarkupSafe                3.0.2
# matplotlib                3.10.0
# matplotlib-inline         0.1.7
# mistune                   3.1.0
# multitasking              0.0.11
# mysql-connector-python    9.1.0
# nbclient                  0.10.2
# nbconvert                 7.16.5
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.3.2
# notebook_shim             0.2.4
# numpy                     2.2.1
# opencv-python             4.10.0.84
# overrides                 7.7.0
# packaging                 24.2
# pandas                    2.2.3
# pandocfilters             1.5.1
# parso                     0.8.4
# peewee                    3.17.8
# pexpect                   4.9.0
# pillow                    11.1.0
# pip                       24.3.1
# platformdirs              4.3.6
# prometheus_client         0.21.1
# prompt_toolkit            3.0.48
# psutil                    6.1.1
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pycparser                 2.22
# Pygments                  2.19.1
# pyparsing                 3.2.1
# pytesseract               0.3.13
# python-dateutil           2.9.0.post0
# python-dotenv             1.0.1
# python-json-logger        3.2.1
# pytz                      2024.2
# PyYAML                    6.0.2
# pyzmq                     26.2.0
# referencing               0.35.1
# requests                  2.32.3
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   0.22.3
# scikit-learn              1.6.1
# scipy                     1.15.0
# Send2Trash                1.8.3
# setuptools                75.8.0
# six                       1.17.0
# sniffio                   1.3.1
# soupsieve                 2.6
# stack-data                0.6.3
# terminado                 0.18.1
# threadpoolctl             3.5.0
# tinycss2                  1.4.0
# tornado                   6.4.2
# traitlets                 5.14.3
# types-python-dateutil     2.9.0.20241206
# typing_extensions         4.12.2
# tzdata                    2024.2
# uri-template              1.3.0
# urllib3                   2.3.0
# wcwidth                   0.2.13
# webcolors                 24.11.1
# webencodings              0.5.1
# websocket-client          1.8.0
# Werkzeug                  3.1.3
# widgetsnbextension        4.0.13
# yfinance                  0.2.51
# Note: you may need to restart the kernel to use updated packages.

# %%
x = np.random.randint(1, 10)

# %%
print(x)
# Out:
# 8

# %%
clear

# %%
ticker = "AAPL"

# %%
import yfinance as yf

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
stockprices = yf.Ticker(ticker).history(period="1d", interval="1m", actions=False)
stockprices['Target'] = stockprices['Close'].shift(-1)

# %%
stockprices = stockprices.dropna()

# %%
print(stockprices)
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2025-01-10 09:30:00-05:00  239.964996  239.964996  239.964996  239.964996
# 2025-01-10 09:31:00-05:00  239.964996  240.149994  238.529999  238.951202
# 2025-01-10 09:32:00-05:00  238.990005  239.339996  238.270004  238.490005
# 2025-01-10 09:33:00-05:00  238.490005  239.000000  238.370102  238.919998
# 2025-01-10 09:34:00-05:00  238.929993  239.100006  238.000000  238.360001
# ...                               ...         ...         ...         ...
# 2025-01-10 15:54:00-05:00  236.789993  236.970001  236.645004  236.941406
# 2025-01-10 15:55:00-05:00  236.910004  237.240005  236.820007  236.884399
# 2025-01-10 15:56:00-05:00  236.880005  236.979996  236.830002  236.889999
# 2025-01-10 15:57:00-05:00  236.899994  237.289993  236.899994  237.259995
# 2025-01-10 15:58:00-05:00  237.270004  237.270004  236.975006  236.975006
#
#                             Volume      Target
# Datetime
# 2025-01-10 09:30:00-05:00  2520068  238.951202
# 2025-01-10 09:31:00-05:00   500215  238.490005
# 2025-01-10 09:32:00-05:00   294861  238.919998
# 2025-01-10 09:33:00-05:00   260902  238.360001
# 2025-01-10 09:34:00-05:00   494977  238.750000
# ...                            ...         ...
# 2025-01-10 15:54:00-05:00   206754  236.884399
# 2025-01-10 15:55:00-05:00   376959  236.889999
# 2025-01-10 15:56:00-05:00   298481  237.259995
# 2025-01-10 15:57:00-05:00   330918  236.975006
# 2025-01-10 15:58:00-05:00   391398  236.929993
#
# [389 rows x 6 columns]

# %%
stockprices.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Datetime'>

# %%
fifty_stockprices = stockprices.head(50)

# %%
fifty_stockprices.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Datetime'>
